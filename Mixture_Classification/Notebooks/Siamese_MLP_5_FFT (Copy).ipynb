# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from itertools import combinations
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from torch.utils.data import TensorDataset, DataLoader
from joblib import Parallel, delayed

# %%
# ─── Utilities ────────────────────────────────────────────────────────────────
lam, p, niter = 1e4, 0.01, 10
def baseline_als(y):
    L = len(y)
    D = np.diff(np.eye(L), 2)
    D = lam * D.dot(D.T)
    w = np.ones(L)
    for _ in range(niter):
        b = np.linalg.solve(np.diag(w) + D, w * y)
        w = p * (y > b) + (1 - p) * (y < b)
    return b

def preprocess_raman_single(spectrum):
    """
    Raman tower: baseline-correct → L2-normalize → abs.
    (Same as your original preprocess_single.)
    """
    b = baseline_als(spectrum)
    c = spectrum - b
    norm = np.linalg.norm(c)
    out = c / norm if norm > 0 else c
    return np.abs(out)

def preprocess_fft_single(spectrum):
    """
    FFT tower: baseline-correct → FFT magnitude (log1p) → L2-normalize.
    Must match what you used when training siamese_mixture_fft.pth.
    """
    b = baseline_als(spectrum)
    c = spectrum - b
    fft_vals = np.fft.rfft(c)
    mag = np.abs(fft_vals)
    mag = np.log1p(mag)
    norm = np.linalg.norm(mag)
    out = mag / norm if norm > 0 else mag
    return out

def floatify_cols(df):
    new = []
    for c in df.columns:
        if c in ('Label', 'Label 1', 'Label 2'):
            new.append(c)
        else:
            new.append(float(c))
    df.columns = new

# %%
# ─── 1) Load reference_v2 ─────────────────────────────────────────────────────
ref_df = pd.read_csv('reference_v2.csv')
floatify_cols(ref_df)
wav_cols   = [c for c in ref_df.columns if c != 'Label']
ref_specs  = ref_df[wav_cols].values       # (n_ref_samples, n_waves)
ref_labels = ref_df['Label'].values        # (n_ref_samples,)

# Unique chemical classes
classes    = sorted(np.unique(ref_labels))
C = len(classes)
class_to_i = {c:i for i,c in enumerate(classes)}

# %%
# ─── 2) Generate synthetic mixtures (raw domain) ──────────────────────────────
ratios = np.arange(0.05, 1.0, 0.05)
noise_level = 0.01
n_per_ratio = 10

synth_specs = []
synth_labels = []
for (i, ci), (j, cj) in combinations(enumerate(classes), 2):
    idx_i = np.where(ref_labels == ci)[0]
    idx_j = np.where(ref_labels == cj)[0]
    for r in ratios:
        for _ in range(n_per_ratio):
            spec_i = ref_specs[np.random.choice(idx_i)]
            spec_j = ref_specs[np.random.choice(idx_j)]
            mix = r * spec_i + (1-r) * spec_j
            mix += np.random.normal(scale=noise_level, size=mix.shape)
            synth_specs.append(mix)
            synth_labels.append((ci, cj))
synth_specs = np.array(synth_specs)
print("Synthetic raw spectra:", synth_specs.shape)
# Out:
# Synthetic raw spectra: (12540, 1024)

# %%
# ─── 3) Build Raman + FFT inputs for synthetic ────────────────────────────────
synth_raman = np.vstack(
    Parallel(n_jobs=-1, verbose=5)(
        delayed(preprocess_raman_single)(spec) for spec in synth_specs
    )
)
print("Synthetic Raman preproc:", synth_raman.shape)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 1088 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 1394 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=-1)]: Done 1736 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 2114 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 2528 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 2978 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 3464 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 3986 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 4544 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 5138 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 5768 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 6434 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 7136 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 7874 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 8648 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 9458 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 10304 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 11186 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 12104 tasks      | elapsed:  6.2min
# Synthetic Raman preproc: (12540, 1024)
# [Parallel(n_jobs=-1)]: Done 12540 out of 12540 | elapsed:  6.4min finished

# %%
synth_fft = np.vstack(
    Parallel(n_jobs=-1, verbose=5)(
        delayed(preprocess_fft_single)(spec) for spec in synth_specs
    )
)
print("Synthetic FFT preproc:", synth_fft.shape)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 1088 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 1394 tasks      | elapsed:   43.9s
# [Parallel(n_jobs=-1)]: Done 1736 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=-1)]: Done 2114 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 2528 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 2978 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 3464 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 3986 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 4544 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 5138 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 5768 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 6434 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 7136 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 7874 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 8648 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 9458 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 10304 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 11186 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 12104 tasks      | elapsed:  6.3min
# Synthetic FFT preproc: (12540, 513)
# [Parallel(n_jobs=-1)]: Done 12540 out of 12540 | elapsed:  6.5min finished

# %%
# ─── 4) Siamese architecture (shared definition) ─────────────────────────────
class SiameseNet(nn.Module):
    def __init__(self, input_len, embed_dim=64):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv1d(1,16,7,padding=3), nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(16,32,5,padding=2), nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Flatten(),
            nn.Linear((input_len//4)*32, embed_dim),
            nn.ReLU()
        )
    def forward(self,x):
        z = self.encoder(x)
        return F.normalize(z, dim=1)

# Raman Siamese (trained on Raman features)
siamese_raman = SiameseNet(input_len=ref_specs.shape[1], embed_dim=64)
siamese_raman.load_state_dict(torch.load('siamese_mixture.pth', map_location='cpu'))
siamese_raman.eval()

# FFT Siamese (trained on FFT features)
input_len_fft = synth_fft.shape[1]
siamese_fft = SiameseNet(input_len=input_len_fft, embed_dim=64)
siamese_fft.load_state_dict(torch.load('siamese_mixture_fft.pth', map_location='cpu'))
siamese_fft.eval()
# Out:
# SiameseNet(
#   (encoder): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(7,), stride=(1,), padding=(3,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv1d(16, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (4): ReLU()
#     (5): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=4096, out_features=64, bias=True)
#     (8): ReLU()
#   )
# )

# %%
# ─── 5) Embed synthetic mixtures with BOTH towers ────────────────────────────
with torch.no_grad():
    ten_raman = torch.tensor(synth_raman, dtype=torch.float32).unsqueeze(1)
    emb_raman = siamese_raman(ten_raman).cpu().numpy()   # (N, 64)

    ten_fft   = torch.tensor(synth_fft, dtype=torch.float32).unsqueeze(1)
    emb_fft   = siamese_fft(ten_fft).cpu().numpy()       # (N, 64)

# %%
# Concatenate embeddings: [Emb A | Emb B]
syn_embeds = np.hstack([emb_raman, emb_fft])            # (N, 128)
print("Concatenated embeddings:", syn_embeds.shape)
# Out:
# Concatenated embeddings: (12540, 128)

# %%
# ─── 6) Build X_synth, Y_synth ────────────────────────────────────────────────
N = len(syn_embeds)
X_synth = syn_embeds
Y_synth = np.zeros((N, C), dtype=int)
for k, (ci, cj) in enumerate(synth_labels):
    Y_synth[k, class_to_i[ci]] = 1
    Y_synth[k, class_to_i[cj]] = 1

# %%
# ─── 7) Split into train/val/test ─────────────────────────────────────────────
X_tmp, X_test_s, Y_tmp, Y_test_s = train_test_split(
    X_synth, Y_synth, test_size=0.10, random_state=0
)
X_train_s, X_val_s, Y_train_s, Y_val_s = train_test_split(
    X_tmp, Y_tmp, test_size=0.1111, random_state=0
)
print("Synthetic train/val/test:", len(X_train_s), len(X_val_s), len(X_test_s))
# Out:
# Synthetic train/val/test: 10032 1254 1254

# %%
# ─── 8) DataLoaders ───────────────────────────────────────────────────────────
batch_size = 64
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(X_train_s, dtype=torch.float32),
        torch.tensor(Y_train_s, dtype=torch.float32)
    ),
    batch_size=batch_size,
    shuffle=True
)
val_loader = DataLoader(
    TensorDataset(
        torch.tensor(X_val_s, dtype=torch.float32),
        torch.tensor(Y_val_s, dtype=torch.float32)
    ),
    batch_size=batch_size
)
test_loader = DataLoader(
    TensorDataset(
        torch.tensor(X_test_s, dtype=torch.float32),
        torch.tensor(Y_test_s, dtype=torch.float32)
    ),
    batch_size=batch_size
)

# %%
# ─── 9) MLP on concatenated embeddings ────────────────────────────────────────
class PresenceNetLogits(nn.Module):
    def __init__(self, D, C):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(D, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, C)   # raw logits
        )
    def forward(self, x):
        return self.net(x)

D = X_train_s.shape[1]   # should be 128 (64 + 64)
C = len(classes)
model_boost = PresenceNetLogits(D, C)

# %%
# pos_weight (class imbalance)
pos = Y_train_s.sum(axis=0)
neg = len(Y_train_s) - pos
pos_weight = torch.tensor((neg/pos).clip(min=1.0), dtype=torch.float32)
print("pos_weight:", pos_weight)
# Out:
# pos_weight: tensor([4.9714, 5.0726, 5.0216, 4.9928, 5.0800, 4.9326, 5.1096, 5.0000, 4.9361,
#         4.9750, 5.0144, 4.9012])

# %%
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = optim.Adam(model_boost.parameters(), lr=1e-3)

num_epochs = 200
for epoch in range(1, num_epochs+1):
    model_boost.train()
    train_loss = 0.0
    for xb, yb in train_loader:
        logits = model_boost(xb)
        loss = criterion(logits, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * xb.size(0)
    train_loss /= len(train_loader.dataset)

    model_boost.eval()
    val_loss = 0.0
    with torch.no_grad():
        for xb, yb in val_loader:
            logits = model_boost(xb)
            val_loss += criterion(logits, yb).item() * xb.size(0)
    val_loss /= len(val_loader.dataset)

    print(f"Epoch {epoch}/{num_epochs} — "
          f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
# Out:
# Epoch 1/200 — Train Loss: 0.9338 | Val Loss: 0.6665
# Epoch 2/200 — Train Loss: 0.5775 | Val Loss: 0.5216
# Epoch 3/200 — Train Loss: 0.4982 | Val Loss: 0.4687
# Epoch 4/200 — Train Loss: 0.4542 | Val Loss: 0.4362
# Epoch 5/200 — Train Loss: 0.4223 | Val Loss: 0.4100
# Epoch 6/200 — Train Loss: 0.3988 | Val Loss: 0.3891
# Epoch 7/200 — Train Loss: 0.3805 | Val Loss: 0.3750
# Epoch 8/200 — Train Loss: 0.3655 | Val Loss: 0.3618
# Epoch 9/200 — Train Loss: 0.3523 | Val Loss: 0.3461
# Epoch 10/200 — Train Loss: 0.3403 | Val Loss: 0.3315
# Epoch 11/200 — Train Loss: 0.3282 | Val Loss: 0.3234
# Epoch 12/200 — Train Loss: 0.3166 | Val Loss: 0.3111
# Epoch 13/200 — Train Loss: 0.3061 | Val Loss: 0.3047
# Epoch 14/200 — Train Loss: 0.2977 | Val Loss: 0.2966
# Epoch 15/200 — Train Loss: 0.2880 | Val Loss: 0.2826
# Epoch 16/200 — Train Loss: 0.2798 | Val Loss: 0.2777
# Epoch 17/200 — Train Loss: 0.2729 | Val Loss: 0.2681
# Epoch 18/200 — Train Loss: 0.2650 | Val Loss: 0.2603
# Epoch 19/200 — Train Loss: 0.2604 | Val Loss: 0.2566
# Epoch 20/200 — Train Loss: 0.2544 | Val Loss: 0.2506
# Epoch 21/200 — Train Loss: 0.2488 | Val Loss: 0.2472
# Epoch 22/200 — Train Loss: 0.2449 | Val Loss: 0.2417
# Epoch 23/200 — Train Loss: 0.2408 | Val Loss: 0.2371
# Epoch 24/200 — Train Loss: 0.2360 | Val Loss: 0.2368
# Epoch 25/200 — Train Loss: 0.2327 | Val Loss: 0.2292
# Epoch 26/200 — Train Loss: 0.2293 | Val Loss: 0.2278
# Epoch 27/200 — Train Loss: 0.2264 | Val Loss: 0.2248
# Epoch 28/200 — Train Loss: 0.2231 | Val Loss: 0.2216
# Epoch 29/200 — Train Loss: 0.2205 | Val Loss: 0.2190
# Epoch 30/200 — Train Loss: 0.2176 | Val Loss: 0.2164
# Epoch 31/200 — Train Loss: 0.2145 | Val Loss: 0.2146
# Epoch 32/200 — Train Loss: 0.2128 | Val Loss: 0.2126
# Epoch 33/200 — Train Loss: 0.2110 | Val Loss: 0.2095
# Epoch 34/200 — Train Loss: 0.2081 | Val Loss: 0.2083
# Epoch 35/200 — Train Loss: 0.2062 | Val Loss: 0.2073
# Epoch 36/200 — Train Loss: 0.2046 | Val Loss: 0.2027
# Epoch 37/200 — Train Loss: 0.2021 | Val Loss: 0.2027
# Epoch 38/200 — Train Loss: 0.2014 | Val Loss: 0.2033
# Epoch 39/200 — Train Loss: 0.1998 | Val Loss: 0.2012
# Epoch 40/200 — Train Loss: 0.1982 | Val Loss: 0.2005
# Epoch 41/200 — Train Loss: 0.1966 | Val Loss: 0.1976
# Epoch 42/200 — Train Loss: 0.1948 | Val Loss: 0.1936
# Epoch 43/200 — Train Loss: 0.1930 | Val Loss: 0.1951
# Epoch 44/200 — Train Loss: 0.1922 | Val Loss: 0.1923
# Epoch 45/200 — Train Loss: 0.1909 | Val Loss: 0.1944
# Epoch 46/200 — Train Loss: 0.1901 | Val Loss: 0.1880
# Epoch 47/200 — Train Loss: 0.1878 | Val Loss: 0.1900
# Epoch 48/200 — Train Loss: 0.1869 | Val Loss: 0.1898
# Epoch 49/200 — Train Loss: 0.1866 | Val Loss: 0.1894
# Epoch 50/200 — Train Loss: 0.1854 | Val Loss: 0.1843
# Epoch 51/200 — Train Loss: 0.1848 | Val Loss: 0.1848
# Epoch 52/200 — Train Loss: 0.1826 | Val Loss: 0.1859
# Epoch 53/200 — Train Loss: 0.1827 | Val Loss: 0.1841
# Epoch 54/200 — Train Loss: 0.1805 | Val Loss: 0.1812
# Epoch 55/200 — Train Loss: 0.1796 | Val Loss: 0.1821
# Epoch 56/200 — Train Loss: 0.1784 | Val Loss: 0.1891
# Epoch 57/200 — Train Loss: 0.1784 | Val Loss: 0.1854
# Epoch 58/200 — Train Loss: 0.1774 | Val Loss: 0.1793
# Epoch 59/200 — Train Loss: 0.1756 | Val Loss: 0.1831
# Epoch 60/200 — Train Loss: 0.1756 | Val Loss: 0.1828
# Epoch 61/200 — Train Loss: 0.1739 | Val Loss: 0.1761
# Epoch 62/200 — Train Loss: 0.1737 | Val Loss: 0.1754
# Epoch 63/200 — Train Loss: 0.1731 | Val Loss: 0.1775
# Epoch 64/200 — Train Loss: 0.1720 | Val Loss: 0.1749
# Epoch 65/200 — Train Loss: 0.1710 | Val Loss: 0.1738
# Epoch 66/200 — Train Loss: 0.1702 | Val Loss: 0.1731
# Epoch 67/200 — Train Loss: 0.1687 | Val Loss: 0.1712
# Epoch 68/200 — Train Loss: 0.1688 | Val Loss: 0.1718
# Epoch 69/200 — Train Loss: 0.1683 | Val Loss: 0.1707
# Epoch 70/200 — Train Loss: 0.1671 | Val Loss: 0.1718
# Epoch 71/200 — Train Loss: 0.1664 | Val Loss: 0.1700
# Epoch 72/200 — Train Loss: 0.1671 | Val Loss: 0.1695
# Epoch 73/200 — Train Loss: 0.1652 | Val Loss: 0.1719
# Epoch 74/200 — Train Loss: 0.1643 | Val Loss: 0.1667
# Epoch 75/200 — Train Loss: 0.1635 | Val Loss: 0.1692
# Epoch 76/200 — Train Loss: 0.1634 | Val Loss: 0.1691
# Epoch 77/200 — Train Loss: 0.1624 | Val Loss: 0.1665
# Epoch 78/200 — Train Loss: 0.1622 | Val Loss: 0.1666
# Epoch 79/200 — Train Loss: 0.1621 | Val Loss: 0.1654
# Epoch 80/200 — Train Loss: 0.1609 | Val Loss: 0.1650
# Epoch 81/200 — Train Loss: 0.1601 | Val Loss: 0.1646
# Epoch 82/200 — Train Loss: 0.1602 | Val Loss: 0.1646
# Epoch 83/200 — Train Loss: 0.1596 | Val Loss: 0.1603
# Epoch 84/200 — Train Loss: 0.1595 | Val Loss: 0.1604
# Epoch 85/200 — Train Loss: 0.1588 | Val Loss: 0.1615
# Epoch 86/200 — Train Loss: 0.1573 | Val Loss: 0.1600
# Epoch 87/200 — Train Loss: 0.1571 | Val Loss: 0.1619
# Epoch 88/200 — Train Loss: 0.1576 | Val Loss: 0.1607
# Epoch 89/200 — Train Loss: 0.1563 | Val Loss: 0.1596
# Epoch 90/200 — Train Loss: 0.1559 | Val Loss: 0.1600
# Epoch 91/200 — Train Loss: 0.1543 | Val Loss: 0.1597
# Epoch 92/200 — Train Loss: 0.1547 | Val Loss: 0.1592
# Epoch 93/200 — Train Loss: 0.1539 | Val Loss: 0.1607
# Epoch 94/200 — Train Loss: 0.1530 | Val Loss: 0.1639
# Epoch 95/200 — Train Loss: 0.1531 | Val Loss: 0.1603
# Epoch 96/200 — Train Loss: 0.1524 | Val Loss: 0.1617
# Epoch 97/200 — Train Loss: 0.1517 | Val Loss: 0.1595
# Epoch 98/200 — Train Loss: 0.1515 | Val Loss: 0.1594
# Epoch 99/200 — Train Loss: 0.1514 | Val Loss: 0.1540
# Epoch 100/200 — Train Loss: 0.1515 | Val Loss: 0.1660
# Epoch 101/200 — Train Loss: 0.1512 | Val Loss: 0.1531
# Epoch 102/200 — Train Loss: 0.1499 | Val Loss: 0.1539
# Epoch 103/200 — Train Loss: 0.1486 | Val Loss: 0.1572
# Epoch 104/200 — Train Loss: 0.1490 | Val Loss: 0.1528
# Epoch 105/200 — Train Loss: 0.1491 | Val Loss: 0.1541
# Epoch 106/200 — Train Loss: 0.1474 | Val Loss: 0.1510
# Epoch 107/200 — Train Loss: 0.1482 | Val Loss: 0.1546
# Epoch 108/200 — Train Loss: 0.1474 | Val Loss: 0.1556
# Epoch 109/200 — Train Loss: 0.1467 | Val Loss: 0.1540
# Epoch 110/200 — Train Loss: 0.1463 | Val Loss: 0.1540
# Epoch 111/200 — Train Loss: 0.1456 | Val Loss: 0.1545
# Epoch 112/200 — Train Loss: 0.1461 | Val Loss: 0.1516
# Epoch 113/200 — Train Loss: 0.1458 | Val Loss: 0.1491
# Epoch 114/200 — Train Loss: 0.1461 | Val Loss: 0.1496
# Epoch 115/200 — Train Loss: 0.1442 | Val Loss: 0.1576
# Epoch 116/200 — Train Loss: 0.1457 | Val Loss: 0.1494
# Epoch 117/200 — Train Loss: 0.1437 | Val Loss: 0.1505
# Epoch 118/200 — Train Loss: 0.1437 | Val Loss: 0.1513
# Epoch 119/200 — Train Loss: 0.1435 | Val Loss: 0.1491
# Epoch 120/200 — Train Loss: 0.1438 | Val Loss: 0.1512
# Epoch 121/200 — Train Loss: 0.1429 | Val Loss: 0.1461
# Epoch 122/200 — Train Loss: 0.1430 | Val Loss: 0.1468
# Epoch 123/200 — Train Loss: 0.1430 | Val Loss: 0.1525
# Epoch 124/200 — Train Loss: 0.1416 | Val Loss: 0.1489
# Epoch 125/200 — Train Loss: 0.1411 | Val Loss: 0.1446
# Epoch 126/200 — Train Loss: 0.1411 | Val Loss: 0.1472
# Epoch 127/200 — Train Loss: 0.1402 | Val Loss: 0.1458
# Epoch 128/200 — Train Loss: 0.1405 | Val Loss: 0.1531
# Epoch 129/200 — Train Loss: 0.1401 | Val Loss: 0.1456
# Epoch 130/200 — Train Loss: 0.1392 | Val Loss: 0.1448
# Epoch 131/200 — Train Loss: 0.1397 | Val Loss: 0.1455
# Epoch 132/200 — Train Loss: 0.1396 | Val Loss: 0.1454
# Epoch 133/200 — Train Loss: 0.1392 | Val Loss: 0.1439
# Epoch 134/200 — Train Loss: 0.1391 | Val Loss: 0.1419
# Epoch 135/200 — Train Loss: 0.1374 | Val Loss: 0.1498
# Epoch 136/200 — Train Loss: 0.1388 | Val Loss: 0.1438
# Epoch 137/200 — Train Loss: 0.1389 | Val Loss: 0.1469
# Epoch 138/200 — Train Loss: 0.1378 | Val Loss: 0.1450
# Epoch 139/200 — Train Loss: 0.1366 | Val Loss: 0.1444
# Epoch 140/200 — Train Loss: 0.1360 | Val Loss: 0.1427
# Epoch 141/200 — Train Loss: 0.1371 | Val Loss: 0.1435
# Epoch 142/200 — Train Loss: 0.1367 | Val Loss: 0.1452
# Epoch 143/200 — Train Loss: 0.1367 | Val Loss: 0.1410
# Epoch 144/200 — Train Loss: 0.1362 | Val Loss: 0.1420
# Epoch 145/200 — Train Loss: 0.1357 | Val Loss: 0.1404
# Epoch 146/200 — Train Loss: 0.1345 | Val Loss: 0.1476
# Epoch 147/200 — Train Loss: 0.1348 | Val Loss: 0.1415
# Epoch 148/200 — Train Loss: 0.1343 | Val Loss: 0.1415
# Epoch 149/200 — Train Loss: 0.1340 | Val Loss: 0.1413
# Epoch 150/200 — Train Loss: 0.1341 | Val Loss: 0.1425
# Epoch 151/200 — Train Loss: 0.1343 | Val Loss: 0.1428
# Epoch 152/200 — Train Loss: 0.1341 | Val Loss: 0.1392
# Epoch 153/200 — Train Loss: 0.1324 | Val Loss: 0.1426
# Epoch 154/200 — Train Loss: 0.1325 | Val Loss: 0.1420
# Epoch 155/200 — Train Loss: 0.1327 | Val Loss: 0.1375
# Epoch 156/200 — Train Loss: 0.1324 | Val Loss: 0.1435
# Epoch 157/200 — Train Loss: 0.1334 | Val Loss: 0.1411
# Epoch 158/200 — Train Loss: 0.1320 | Val Loss: 0.1376
# Epoch 159/200 — Train Loss: 0.1314 | Val Loss: 0.1414
# Epoch 160/200 — Train Loss: 0.1321 | Val Loss: 0.1387
# Epoch 161/200 — Train Loss: 0.1307 | Val Loss: 0.1437
# Epoch 162/200 — Train Loss: 0.1311 | Val Loss: 0.1371
# Epoch 163/200 — Train Loss: 0.1298 | Val Loss: 0.1378
# Epoch 164/200 — Train Loss: 0.1309 | Val Loss: 0.1385
# Epoch 165/200 — Train Loss: 0.1308 | Val Loss: 0.1377
# Epoch 166/200 — Train Loss: 0.1308 | Val Loss: 0.1385
# Epoch 167/200 — Train Loss: 0.1293 | Val Loss: 0.1374
# Epoch 168/200 — Train Loss: 0.1303 | Val Loss: 0.1397
# Epoch 169/200 — Train Loss: 0.1293 | Val Loss: 0.1409
# Epoch 170/200 — Train Loss: 0.1295 | Val Loss: 0.1358
# Epoch 171/200 — Train Loss: 0.1289 | Val Loss: 0.1346
# Epoch 172/200 — Train Loss: 0.1288 | Val Loss: 0.1379
# Epoch 173/200 — Train Loss: 0.1289 | Val Loss: 0.1370
# Epoch 174/200 — Train Loss: 0.1284 | Val Loss: 0.1355
# Epoch 175/200 — Train Loss: 0.1283 | Val Loss: 0.1368
# Epoch 176/200 — Train Loss: 0.1273 | Val Loss: 0.1369
# Epoch 177/200 — Train Loss: 0.1287 | Val Loss: 0.1343
# Epoch 178/200 — Train Loss: 0.1280 | Val Loss: 0.1334
# Epoch 179/200 — Train Loss: 0.1268 | Val Loss: 0.1377
# Epoch 180/200 — Train Loss: 0.1282 | Val Loss: 0.1337
# Epoch 181/200 — Train Loss: 0.1271 | Val Loss: 0.1399
# Epoch 182/200 — Train Loss: 0.1261 | Val Loss: 0.1345
# Epoch 183/200 — Train Loss: 0.1259 | Val Loss: 0.1392
# Epoch 184/200 — Train Loss: 0.1266 | Val Loss: 0.1383
# Epoch 185/200 — Train Loss: 0.1264 | Val Loss: 0.1348
# Epoch 186/200 — Train Loss: 0.1258 | Val Loss: 0.1391
# Epoch 187/200 — Train Loss: 0.1260 | Val Loss: 0.1377
# Epoch 188/200 — Train Loss: 0.1260 | Val Loss: 0.1328
# Epoch 189/200 — Train Loss: 0.1260 | Val Loss: 0.1317
# Epoch 190/200 — Train Loss: 0.1243 | Val Loss: 0.1403
# Epoch 191/200 — Train Loss: 0.1248 | Val Loss: 0.1389
# Epoch 192/200 — Train Loss: 0.1251 | Val Loss: 0.1375
# Epoch 193/200 — Train Loss: 0.1252 | Val Loss: 0.1354
# Epoch 194/200 — Train Loss: 0.1255 | Val Loss: 0.1349
# Epoch 195/200 — Train Loss: 0.1239 | Val Loss: 0.1329
# Epoch 196/200 — Train Loss: 0.1248 | Val Loss: 0.1376
# Epoch 197/200 — Train Loss: 0.1237 | Val Loss: 0.1335
# Epoch 198/200 — Train Loss: 0.1229 | Val Loss: 0.1296
# Epoch 199/200 — Train Loss: 0.1246 | Val Loss: 0.1343
# Epoch 200/200 — Train Loss: 0.1230 | Val Loss: 0.1314

# %%
# ─── 10) Real mixtures: build Raman + FFT, embed, concat, classify ───────────
mix_df = pd.read_csv('mixtures_dataset.csv')
floatify_cols(mix_df)

wav_cols = [c for c in mix_df.columns if c not in ('Label 1', 'Label 2')]
mix_specs = mix_df[wav_cols].values.astype(float)

mix_raman = np.vstack(
    Parallel(n_jobs=-1, verbose=5)(
        delayed(preprocess_raman_single)(spec) for spec in mix_specs
    )
)
print("Mixtures Raman preproc:", mix_raman.shape)

mix_fft = np.vstack(
    Parallel(n_jobs=-1, verbose=5)(
        delayed(preprocess_fft_single)(spec) for spec in mix_specs
    )
)
print("Mixtures FFT preproc:", mix_fft.shape)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 580 out of 580 | elapsed:   17.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Mixtures Raman preproc: (580, 1024)
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:   12.4s
# Mixtures FFT preproc: (580, 513)
# [Parallel(n_jobs=-1)]: Done 580 out of 580 | elapsed:   17.9s finished

# %%
with torch.no_grad():
    mix_emb_raman = siamese_raman(
        torch.tensor(mix_raman, dtype=torch.float32).unsqueeze(1)
    ).cpu().numpy()
    mix_emb_fft = siamese_fft(
        torch.tensor(mix_fft, dtype=torch.float32).unsqueeze(1)
    ).cpu().numpy()

mix_embeds = np.hstack([mix_emb_raman, mix_emb_fft])   # (N_real, 128)

pairs = list(zip(mix_df['Label 1'], mix_df['Label 2']))
N_real = len(mix_df)
Y_real = np.zeros((N_real, C), dtype=int)
for i, (l1, l2) in enumerate(pairs):
    Y_real[i, class_to_i[l1]] = 1
    Y_real[i, class_to_i[l2]] = 1

model_boost.eval()
preds = model_boost(torch.tensor(mix_embeds, dtype=torch.float32)).detach().numpy()
Y_pred_real = (preds > 0.0).astype(int)

supports = Y_real.sum(axis=0)
valid_idx = [i for i, s in enumerate(supports) if s > 0]
valid_labels = [classes[i] for i in valid_idx]

y_true_filt = Y_real[:, valid_idx]
y_pred_filt = Y_pred_real[:, valid_idx]

print("\nReal Mixtures Validation Report (labels with support > 0):")
print(classification_report(
    y_true_filt,
    y_pred_filt,
    target_names=valid_labels,
    zero_division=0
))
# Out:
# Real Mixtures Validation Report (labels with support > 0):
#                        precision    recall  f1-score   support
#
#       1-dodecanethiol       0.86      0.88      0.87       243
#  6-mercapto-1-hexanol       0.90      0.33      0.49       108
#               benzene       1.00      1.00      1.00       193
#          benzenethiol       0.89      1.00      0.94        72
#                  etoh       1.00      1.00      1.00       121
#                  meoh       1.00      0.88      0.94       243
# n,n-dimethylformamide       0.97      1.00      0.99        72
#              pyridine       1.00      1.00      1.00       108
#
#             micro avg       0.95      0.89      0.92      1160
#             macro avg       0.95      0.89      0.90      1160
#          weighted avg       0.95      0.89      0.91      1160
#           samples avg       0.95      0.89      0.91      1160

# %%
import numpy as np
import torch

model_boost.eval()
with torch.no_grad():
    logits = model_boost(torch.tensor(mix_embeds, dtype=torch.float32)).cpu().numpy()  # (N, C)

# Convert logits -> probabilities
probs = 1 / (1 + np.exp(-logits))

# Use prob threshold (0.5)
thr = 0.5
Y_pred_real = (probs >= thr).astype(int)

# (Optional) equivalently, threshold logits at 0.0:
# Y_pred_real = (logits >= 0.0).astype(int)
# Out:
# /tmp/ipykernel_24965/2182551093.py:9: RuntimeWarning: overflow encountered in exp
#   probs = 1 / (1 + np.exp(-logits))

# %%
from collections import Counter

target_label = "6-mercapto-1-hexanol"
k = class_to_i[target_label]

true_pos = (Y_real[:, k] == 1)          # mercapto truly present
pred_neg = (probs[:, k] < thr)          # model did NOT predict mercapto
fn_mask = true_pos & pred_neg           # false negatives for mercapto
fn_idx = np.where(fn_mask)[0]

print("Mercapto false negatives:", len(fn_idx), "out of", int(true_pos.sum()), "true mercapto samples")

# Top-2 predicted labels for each FN (by probability)
top2_idx = np.argsort(probs[fn_idx], axis=1)[:, -2:][:, ::-1]  # indices of top2, descending

top2_labels = [tuple(classes[j] for j in row) for row in top2_idx]  # (label1, label2) tuples
pair_counts = Counter(top2_labels)

print("\nMost common TOP-2 predicted label pairs for mercapto FNs:")
for pair, cnt in pair_counts.most_common(15):
    print(f"{cnt:4d}  {pair}")

# Also: which single labels appear most in top2 (helps see dominant confusion class)
single_counts = Counter([lbl for pair in top2_labels for lbl in pair])

print("\nMost common individual labels appearing in TOP-2 for mercapto FNs:")
for lbl, cnt in single_counts.most_common(15):
    print(f"{cnt:4d}  {lbl}")

# Optional: print a few example rows with their true pair + top2 predictions + mercapto score
print("\nExamples (index | true labels | mercapto prob | top2 preds):")
for i in fn_idx[:10]:
    true_pair = tuple([classes[j] for j in np.where(Y_real[i] == 1)[0]])
    top2 = tuple(classes[j] for j in np.argsort(probs[i])[-2:][::-1])
    print(i, "|", true_pair, "|", f"{probs[i, k]:.3f}", "|", top2)
# Out:
# Mercapto false negatives: 72 out of 108 true mercapto samples
#
# Most common TOP-2 predicted label pairs for mercapto FNs:
#   36  ('n,n-dimethylformamide', '1,9-nonanedithiol')
#   30  ('benzene', '1-dodecanethiol')
#    6  ('benzene', '1-undecanethiol')
#
# Most common individual labels appearing in TOP-2 for mercapto FNs:
#   36  benzene
#   36  n,n-dimethylformamide
#   36  1,9-nonanedithiol
#   30  1-dodecanethiol
#    6  1-undecanethiol
#
# Examples (index | true labels | mercapto prob | top2 preds):
# 0 | ('6-mercapto-1-hexanol', 'benzene') | 0.269 | ('benzene', '1-dodecanethiol')
# 1 | ('6-mercapto-1-hexanol', 'benzene') | 0.291 | ('benzene', '1-dodecanethiol')
# 2 | ('6-mercapto-1-hexanol', 'benzene') | 0.291 | ('benzene', '1-dodecanethiol')
# 3 | ('6-mercapto-1-hexanol', 'benzene') | 0.232 | ('benzene', '1-dodecanethiol')
# 4 | ('6-mercapto-1-hexanol', 'benzene') | 0.291 | ('benzene', '1-dodecanethiol')
# 5 | ('6-mercapto-1-hexanol', 'benzene') | 0.256 | ('benzene', '1-dodecanethiol')
# 6 | ('6-mercapto-1-hexanol', 'benzene') | 0.311 | ('benzene', '1-undecanethiol')
# 7 | ('6-mercapto-1-hexanol', 'benzene') | 0.266 | ('benzene', '1-dodecanethiol')
# 8 | ('6-mercapto-1-hexanol', 'benzene') | 0.305 | ('benzene', '1-undecanethiol')
# 9 | ('6-mercapto-1-hexanol', 'benzene') | 0.298 | ('benzene', '1-dodecanethiol')

# %%
import matplotlib.pyplot as plt

pos_scores = probs[true_pos, k]      # P(mercapto) when mercapto is truly present
neg_scores = probs[~true_pos, k]     # P(mercapto) when mercapto is truly absent

print("Mercapto score stats:")
print("  positives: mean=", float(pos_scores.mean()), "median=", float(np.median(pos_scores)))
print("  negatives: mean=", float(neg_scores.mean()), "median=", float(np.median(neg_scores)))

plt.figure()
plt.hist(pos_scores, bins=40, alpha=0.6, label="mercapto TRUE present")
plt.hist(neg_scores, bins=40, alpha=0.6, label="mercapto TRUE absent")
plt.axvline(thr, linestyle="--", label=f"threshold={thr}")
plt.xlabel("P(6-mercapto-1-hexanol) = sigmoid(logit)")
plt.ylabel("Count")
plt.title("Mercapto score distribution (positive vs negative)")
plt.legend()
plt.show()
# Out:
# Mercapto score stats:
#   positives: mean= 0.5023772120475769 median= 0.32458925247192383
#   negatives: mean= 0.01497313566505909 median= 6.884237109261448e-07

# %%
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(true_pos.astype(int), probs[:, k])
print("Mercapto ROC-AUC:", auc)
# Out:
# Mercapto ROC-AUC: 0.9893086942875078

# %%
# ─── 9) Evaluate synthetic test set ────────────────────────────────────────────
model_boost.eval()
yp, yt = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        yp.append(model_boost(xb).numpy())
        yt.append(yb.numpy())
y_pred = (np.vstack(yp)>0.0).astype(int)
y_true = np.vstack(yt)
print("\nSynthetic Test Classification Report:")
print(classification_report(y_true, y_pred, target_names=classes))
# Out:
# Synthetic Test Classification Report:
#                               precision    recall  f1-score   support
#
#            1,9-nonanedithiol       0.80      0.96      0.88       196
#              1-dodecanethiol       0.53      0.96      0.69       225
#              1-undecanethiol       0.45      1.00      0.62       208
#         6-mercapto-1-hexanol       0.72      0.92      0.80       204
#                      benzene       1.00      1.00      1.00       235
#                 benzenethiol       0.97      0.99      0.98       195
#                         dmmp       1.00      1.00      1.00       220
#                         etoh       0.97      1.00      0.98       217
#                         meoh       0.94      0.93      0.94       184
#        n,n-dimethylformamide       0.99      1.00      1.00       212
#                     pyridine       0.99      0.99      0.99       223
# tris(2-ethylhexyl) phosphate       0.98      1.00      0.99       189
#
#                    micro avg       0.81      0.98      0.88      2508
#                    macro avg       0.86      0.98      0.91      2508
#                 weighted avg       0.86      0.98      0.91      2508
#                  samples avg       0.85      0.98      0.90      2508

# %%
model_boost.eval()
all_logits, all_true = [], []

with torch.no_grad():
    for xb, yb in test_loader:
        all_logits.append(model_boost(xb).cpu().numpy())  # logits
        all_true.append(yb.cpu().numpy())                 # 0/1 labels

logits = np.vstack(all_logits)   # (N_test, C)
y_true = np.vstack(all_true)     # (N_test, C)

# probs = sigmoid(logits)
probs = 1 / (1 + np.exp(-logits))

thr = 0.5
y_pred = (probs >= thr).astype(int)   # prediction based on probability
# equivalent: y_pred = (logits >= 0.0).astype(int)
# Out:
# /tmp/ipykernel_24965/3806194797.py:13: RuntimeWarning: overflow encountered in exp
#   probs = 1 / (1 + np.exp(-logits))

# %%
def analyze_label(k, label_name, y_true, probs, thr=0.5, topk_pairs=10, plot=False, bins=40):
    true_pos = (y_true[:, k] == 1)
    pred_neg = (probs[:, k] < thr)
    fn_mask = true_pos & pred_neg
    fn_idx = np.where(fn_mask)[0]

    n_pos = int(true_pos.sum())
    n_fn  = len(fn_idx)

    # ROC-AUC (only valid if both classes exist)
    auc = None
    if len(np.unique(true_pos.astype(int))) == 2:
        auc = roc_auc_score(true_pos.astype(int), probs[:, k])

    # Score stats
    pos_scores = probs[true_pos, k]
    neg_scores = probs[~true_pos, k]

    print("\n" + "="*80)
    print(f"Label: {label_name}  (index {k})")
    print(f"Positives: {n_pos} | False Negatives @ thr={thr}: {n_fn} ({(n_fn/max(n_pos,1))*100:.1f}%)")
    if auc is not None:
        print(f"ROC-AUC: {auc:.4f}")

    print("Score stats:")
    print(f"  positives: mean={float(pos_scores.mean()):.4f}  median={float(np.median(pos_scores)):.4f}")
    print(f"  negatives: mean={float(neg_scores.mean()):.6f}  median={float(np.median(neg_scores)):.6f}")

    # Where do FNs go? (top-2 predicted labels in each FN sample)
    if n_fn > 0:
        top2_idx = np.argsort(probs[fn_idx], axis=1)[:, -2:][:, ::-1]
        top2_labels = [tuple(classes[j] for j in row) for row in top2_idx]
        pair_counts = Counter(top2_labels)

        print("\nMost common TOP-2 predicted label pairs for FNs:")
        for pair, cnt in pair_counts.most_common(topk_pairs):
            print(f"{cnt:4d}  {pair}")

        single_counts = Counter([lbl for pair in top2_labels for lbl in pair])
        print("\nMost common individual labels appearing in TOP-2 for FNs:")
        for lbl, cnt in single_counts.most_common(topk_pairs):
            print(f"{cnt:4d}  {lbl}")

        print("\nExamples (index | true labels | P(this label) | top2 preds):")
        for i in fn_idx[:10]:
            true_pair = tuple([classes[j] for j in np.where(y_true[i] == 1)[0]])
            top2 = tuple(classes[j] for j in np.argsort(probs[i])[-2:][::-1])
            print(i, "|", true_pair, "|", f"{probs[i, k]:.3f}", "|", top2)

    # Plot histogram
    if plot:
        plt.figure()
        plt.hist(pos_scores, bins=bins, alpha=0.6, label=f"{label_name} TRUE present")
        plt.hist(neg_scores, bins=bins, alpha=0.6, label=f"{label_name} TRUE absent")
        plt.axvline(thr, linestyle="--", label=f"threshold={thr}")
        plt.xlabel(f"P({label_name}) = sigmoid(logit)")
        plt.ylabel("Count")
        plt.title(f"{label_name} score distribution (positive vs negative)")
        plt.legend()
        plt.show()

# Run for every label
for k, label_name in enumerate(classes):
    analyze_label(k, label_name, y_true, probs, thr=0.5, topk_pairs=10, plot=False)
# Out:
# ================================================================================
# Label: 1,9-nonanedithiol  (index 0)
# Positives: 196 | False Negatives @ thr=0.5: 7 (3.6%)
# ROC-AUC: 0.9923
# Score stats:
#   positives: mean=0.9325  median=0.9999
#   negatives: mean=0.071499  median=0.000032
#
# Most common TOP-2 predicted label pairs for FNs:
#    2  ('n,n-dimethylformamide', '6-mercapto-1-hexanol')
#    2  ('benzene', '6-mercapto-1-hexanol')
#    2  ('dmmp', '1-dodecanethiol')
#    1  ('dmmp', '6-mercapto-1-hexanol')
#
# Most common individual labels appearing in TOP-2 for FNs:
#    5  6-mercapto-1-hexanol
#    3  dmmp
#    2  n,n-dimethylformamide
#    2  benzene
#    2  1-dodecanethiol
#
# Examples (index | true labels | P(this label) | top2 preds):
# 41 | ('1,9-nonanedithiol', 'n,n-dimethylformamide') | 0.057 | ('n,n-dimethylformamide', '6-mercapto-1-hexanol')
# 107 | ('1,9-nonanedithiol', 'dmmp') | 0.076 | ('dmmp', '6-mercapto-1-hexanol')
# 461 | ('1,9-nonanedithiol', 'benzene') | 0.267 | ('benzene', '6-mercapto-1-hexanol')
# 468 | ('1,9-nonanedithiol', 'dmmp') | 0.123 | ('dmmp', '1-dodecanethiol')
# 510 | ('1,9-nonanedithiol', 'dmmp') | 0.251 | ('dmmp', '1-dodecanethiol')
# 991 | ('1,9-nonanedithiol', 'benzene') | 0.438 | ('benzene', '6-mercapto-1-hexanol')
# 1152 | ('1,9-nonanedithiol', 'n,n-dimethylformamide') | 0.055 | ('n,n-dimethylformamide', '6-mercapto-1-hexanol')
#
# ================================================================================
# Label: 1-dodecanethiol  (index 1)
# Positives: 225 | False Negatives @ thr=0.5: 8 (3.6%)
# ROC-AUC: 0.9642
# Score stats:
#   positives: mean=0.8710  median=0.9252
#   negatives: mean=0.161163  median=0.000003
#
# Most common TOP-2 predicted label pairs for FNs:
#    3  ('n,n-dimethylformamide', '6-mercapto-1-hexanol')
#    2  ('benzene', '6-mercapto-1-hexanol')
#    2  ('dmmp', '6-mercapto-1-hexanol')
#    1  ('dmmp', '1-undecanethiol')
#
# Most common individual labels appearing in TOP-2 for FNs:
#    7  6-mercapto-1-hexanol
#    3  n,n-dimethylformamide
#    3  dmmp
#    2  benzene
#    1  1-undecanethiol
#
# Examples (index | true labels | P(this label) | top2 preds):
# 81 | ('1-dodecanethiol', 'n,n-dimethylformamide') | 0.416 | ('n,n-dimethylformamide', '6-mercapto-1-hexanol')
# 171 | ('1-dodecanethiol', 'benzene') | 0.470 | ('benzene', '6-mercapto-1-hexanol')
# 174 | ('1-dodecanethiol', 'dmmp') | 0.341 | ('dmmp', '6-mercapto-1-hexanol')
# 280 | ('1-dodecanethiol', 'n,n-dimethylformamide') | 0.487 | ('n,n-dimethylformamide', '6-mercapto-1-hexanol')
# 807 | ('1-dodecanethiol', 'n,n-dimethylformamide') | 0.480 | ('n,n-dimethylformamide', '6-mercapto-1-hexanol')
# 845 | ('1-dodecanethiol', 'dmmp') | 0.472 | ('dmmp', '1-undecanethiol')
# 928 | ('1-dodecanethiol', 'dmmp') | 0.333 | ('dmmp', '6-mercapto-1-hexanol')
# 1126 | ('1-dodecanethiol', 'benzene') | 0.464 | ('benzene', '6-mercapto-1-hexanol')
#
# ================================================================================
# Label: 1-undecanethiol  (index 2)
# Positives: 208 | False Negatives @ thr=0.5: 1 (0.5%)
# ROC-AUC: 0.9207
# Score stats:
#   positives: mean=0.8314  median=0.8520
#   negatives: mean=0.221147  median=0.004280
#
# Most common TOP-2 predicted label pairs for FNs:
#    1  ('dmmp', '1-dodecanethiol')
#
# Most common individual labels appearing in TOP-2 for FNs:
#    1  dmmp
#    1  1-dodecanethiol
#
# Examples (index | true labels | P(this label) | top2 preds):
# 828 | ('1-undecanethiol', 'dmmp') | 0.459 | ('dmmp', '1-dodecanethiol')
#
# ================================================================================
# Label: 6-mercapto-1-hexanol  (index 3)
# Positives: 204 | False Negatives @ thr=0.5: 17 (8.3%)
# ROC-AUC: 0.9857
# Score stats:
#   positives: mean=0.8860  median=0.9840
#   negatives: mean=0.096995  median=0.000018
#
# Most common TOP-2 predicted label pairs for FNs:
#    7  ('dmmp', '1,9-nonanedithiol')
#    4  ('1-dodecanethiol', '1-undecanethiol')
#    2  ('benzene', '1,9-nonanedithiol')
#    2  ('benzene', '1-undecanethiol')
#    1  ('1,9-nonanedithiol', '1-undecanethiol')
#    1  ('dmmp', '6-mercapto-1-hexanol')
#
# Most common individual labels appearing in TOP-2 for FNs:
#   10  1,9-nonanedithiol
#    8  dmmp
#    7  1-undecanethiol
#    4  benzene
#    4  1-dodecanethiol
#    1  6-mercapto-1-hexanol
#
# Examples (index | true labels | P(this label) | top2 preds):
# 29 | ('6-mercapto-1-hexanol', 'benzene') | 0.385 | ('benzene', '1,9-nonanedithiol')
# 201 | ('6-mercapto-1-hexanol', 'dmmp') | 0.473 | ('dmmp', '1,9-nonanedithiol')
# 263 | ('6-mercapto-1-hexanol', 'dmmp') | 0.495 | ('dmmp', '1,9-nonanedithiol')
# 308 | ('1-dodecanethiol', '6-mercapto-1-hexanol') | 0.121 | ('1-dodecanethiol', '1-undecanethiol')
# 433 | ('1-dodecanethiol', '6-mercapto-1-hexanol') | 0.253 | ('1-dodecanethiol', '1-undecanethiol')
# 434 | ('6-mercapto-1-hexanol', 'dmmp') | 0.462 | ('dmmp', '1,9-nonanedithiol')
# 570 | ('1-dodecanethiol', '6-mercapto-1-hexanol') | 0.258 | ('1-dodecanethiol', '1-undecanethiol')
# 684 | ('6-mercapto-1-hexanol', 'benzene') | 0.400 | ('benzene', '1-undecanethiol')
# 710 | ('6-mercapto-1-hexanol', 'benzene') | 0.385 | ('benzene', '1,9-nonanedithiol')
# 770 | ('6-mercapto-1-hexanol', 'dmmp') | 0.467 | ('dmmp', '1,9-nonanedithiol')
#
# ================================================================================
# Label: benzene  (index 4)
# Positives: 235 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=1.0000  median=1.0000
#   negatives: mean=0.000000  median=0.000000
#
# ================================================================================
# Label: benzenethiol  (index 5)
# Positives: 195 | False Negatives @ thr=0.5: 1 (0.5%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=0.9914  median=1.0000
#   negatives: mean=0.007530  median=0.000000
#
# Most common TOP-2 predicted label pairs for FNs:
#    1  ('benzene', 'etoh')
#
# Most common individual labels appearing in TOP-2 for FNs:
#    1  benzene
#    1  etoh
#
# Examples (index | true labels | P(this label) | top2 preds):
# 456 | ('benzene', 'benzenethiol') | 0.471 | ('benzene', 'etoh')
#
# ================================================================================
# Label: dmmp  (index 6)
# Positives: 220 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=0.9998  median=1.0000
#   negatives: mean=0.002459  median=0.000000
#
# ================================================================================
# Label: etoh  (index 7)
# Positives: 217 | False Negatives @ thr=0.5: 1 (0.5%)
# ROC-AUC: 0.9998
# Score stats:
#   positives: mean=0.9727  median=1.0000
#   negatives: mean=0.017235  median=0.000000
#
# Most common TOP-2 predicted label pairs for FNs:
#    1  ('benzene', '6-mercapto-1-hexanol')
#
# Most common individual labels appearing in TOP-2 for FNs:
#    1  benzene
#    1  6-mercapto-1-hexanol
#
# Examples (index | true labels | P(this label) | top2 preds):
# 586 | ('benzene', 'etoh') | 0.405 | ('benzene', '6-mercapto-1-hexanol')
#
# ================================================================================
# Label: meoh  (index 8)
# Positives: 184 | False Negatives @ thr=0.5: 12 (6.5%)
# ROC-AUC: 0.9978
# Score stats:
#   positives: mean=0.9442  median=1.0000
#   negatives: mean=0.012341  median=0.000000
#
# Most common TOP-2 predicted label pairs for FNs:
#    9  ('benzene', '6-mercapto-1-hexanol')
#    1  ('etoh', 'tris(2-ethylhexyl) phosphate')
#    1  ('benzene', 'meoh')
#    1  ('dmmp', 'tris(2-ethylhexyl) phosphate')
#
# Most common individual labels appearing in TOP-2 for FNs:
#   10  benzene
#    9  6-mercapto-1-hexanol
#    2  tris(2-ethylhexyl) phosphate
#    1  etoh
#    1  meoh
#    1  dmmp
#
# Examples (index | true labels | P(this label) | top2 preds):
# 128 | ('benzene', 'meoh') | 0.350 | ('benzene', '6-mercapto-1-hexanol')
# 162 | ('benzene', 'meoh') | 0.306 | ('benzene', '6-mercapto-1-hexanol')
# 249 | ('etoh', 'meoh') | 0.000 | ('etoh', 'tris(2-ethylhexyl) phosphate')
# 325 | ('benzene', 'meoh') | 0.227 | ('benzene', '6-mercapto-1-hexanol')
# 535 | ('benzene', 'meoh') | 0.465 | ('benzene', 'meoh')
# 562 | ('benzene', 'meoh') | 0.186 | ('benzene', '6-mercapto-1-hexanol')
# 693 | ('benzene', 'meoh') | 0.240 | ('benzene', '6-mercapto-1-hexanol')
# 895 | ('dmmp', 'meoh') | 0.472 | ('dmmp', 'tris(2-ethylhexyl) phosphate')
# 913 | ('benzene', 'meoh') | 0.326 | ('benzene', '6-mercapto-1-hexanol')
# 1036 | ('benzene', 'meoh') | 0.461 | ('benzene', '6-mercapto-1-hexanol')
#
# ================================================================================
# Label: n,n-dimethylformamide  (index 9)
# Positives: 212 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=0.9925  median=1.0000
#   negatives: mean=0.010897  median=0.000000
#
# ================================================================================
# Label: pyridine  (index 10)
# Positives: 223 | False Negatives @ thr=0.5: 2 (0.9%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=0.9871  median=1.0000
#   negatives: mean=0.003064  median=0.000000
#
# Most common TOP-2 predicted label pairs for FNs:
#    1  ('benzene', '6-mercapto-1-hexanol')
#    1  ('benzene', 'meoh')
#
# Most common individual labels appearing in TOP-2 for FNs:
#    2  benzene
#    1  6-mercapto-1-hexanol
#    1  meoh
#
# Examples (index | true labels | P(this label) | top2 preds):
# 419 | ('benzene', 'pyridine') | 0.249 | ('benzene', '6-mercapto-1-hexanol')
# 1227 | ('benzene', 'pyridine') | 0.186 | ('benzene', 'meoh')
#
# ================================================================================
# Label: tris(2-ethylhexyl) phosphate  (index 11)
# Positives: 189 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 0.9998
# Score stats:
#   positives: mean=0.9832  median=1.0000
#   negatives: mean=0.016350  median=0.000000

# %%
summary = []
for k, label_name in enumerate(classes):
    true_pos = (y_true[:, k] == 1)
    pred_neg = (probs[:, k] < thr)
    fn = int((true_pos & pred_neg).sum())
    tp = int((true_pos & (probs[:, k] >= thr)).sum())
    pos = int(true_pos.sum())
    recall = tp / (pos + 1e-12)

    auc = np.nan
    if len(np.unique(true_pos.astype(int))) == 2:
        auc = roc_auc_score(true_pos.astype(int), probs[:, k])

    summary.append((label_name, pos, recall, fn, auc))

summary_sorted = sorted(summary, key=lambda x: x[2])  # sort by recall
print("\nWorst recall labels @ thr=0.5:")
for row in summary_sorted[:8]:
    print(f"{row[0]:30s} pos={row[1]:4d} recall={row[2]:.3f} FN={row[3]:4d} AUC={row[4]:.3f}")
# Out:
# Worst recall labels @ thr=0.5:
# 6-mercapto-1-hexanol           pos= 204 recall=0.917 FN=  17 AUC=0.986
# meoh                           pos= 184 recall=0.935 FN=  12 AUC=0.998
# 1,9-nonanedithiol              pos= 196 recall=0.964 FN=   7 AUC=0.992
# 1-dodecanethiol                pos= 225 recall=0.964 FN=   8 AUC=0.964
# pyridine                       pos= 223 recall=0.991 FN=   2 AUC=1.000
# benzenethiol                   pos= 195 recall=0.995 FN=   1 AUC=1.000
# 1-undecanethiol                pos= 208 recall=0.995 FN=   1 AUC=0.921
# etoh                           pos= 217 recall=0.995 FN=   1 AUC=1.000

# %%
# --- Embed real mixtures ---
with torch.no_grad():
    mix_emb_raman = siamese_raman(
        torch.tensor(mix_raman, dtype=torch.float32).unsqueeze(1)
    ).cpu().numpy()
    mix_emb_fft = siamese_fft(
        torch.tensor(mix_fft, dtype=torch.float32).unsqueeze(1)
    ).cpu().numpy()

mix_embeds = np.hstack([mix_emb_raman, mix_emb_fft])   # (N_real, 128)

# --- Build Y_real ---
pairs = list(zip(mix_df['Label 1'], mix_df['Label 2']))
N_real = len(mix_df)
Y_real = np.zeros((N_real, C), dtype=int)
for i, (l1, l2) in enumerate(pairs):
    Y_real[i, class_to_i[l1]] = 1
    Y_real[i, class_to_i[l2]] = 1

# --- Model outputs on real mixtures (LOGITS) ---
model_boost.eval()
with torch.no_grad():
    logits = model_boost(torch.tensor(mix_embeds, dtype=torch.float32)).cpu().numpy()  # (N_real, C)

# probs = sigmoid(logits)
probs = 1 / (1 + np.exp(-logits))

thr = 0.5
Y_pred_real = (probs >= thr).astype(int)  # probability-based decision
# equivalent: Y_pred_real = (logits >= 0.0).astype(int)
# Out:
# /tmp/ipykernel_24965/2502353186.py:26: RuntimeWarning: overflow encountered in exp
#   probs = 1 / (1 + np.exp(-logits))

# %%
supports = Y_real.sum(axis=0)
valid_idx = [i for i, s in enumerate(supports) if s > 0]
valid_labels = [classes[i] for i in valid_idx]

y_true_filt = Y_real[:, valid_idx]
y_pred_filt = Y_pred_real[:, valid_idx]

print("\nReal Mixtures Validation Report (labels with support > 0):")
print(classification_report(
    y_true_filt,
    y_pred_filt,
    target_names=valid_labels,
    zero_division=0
))
# Out:
# Real Mixtures Validation Report (labels with support > 0):
#                        precision    recall  f1-score   support
#
#       1-dodecanethiol       0.86      0.88      0.87       243
#  6-mercapto-1-hexanol       0.90      0.33      0.49       108
#               benzene       1.00      1.00      1.00       193
#          benzenethiol       0.89      1.00      0.94        72
#                  etoh       1.00      1.00      1.00       121
#                  meoh       1.00      0.88      0.94       243
# n,n-dimethylformamide       0.97      1.00      0.99        72
#              pyridine       1.00      1.00      1.00       108
#
#             micro avg       0.95      0.89      0.92      1160
#             macro avg       0.95      0.89      0.90      1160
#          weighted avg       0.95      0.89      0.91      1160
#           samples avg       0.95      0.89      0.91      1160

# %%
def analyze_label_on_real(k, label_name, Y_real, probs, thr=0.5, topk_pairs=10, plot=False, bins=40):
    true_pos = (Y_real[:, k] == 1)
    pred_neg = (probs[:, k] < thr)
    fn_mask = true_pos & pred_neg
    fn_idx = np.where(fn_mask)[0]

    n_pos = int(true_pos.sum())
    n_fn  = len(fn_idx)

    # ROC-AUC (only if both classes exist)
    auc = None
    if len(np.unique(true_pos.astype(int))) == 2:
        auc = roc_auc_score(true_pos.astype(int), probs[:, k])

    pos_scores = probs[true_pos, k]
    neg_scores = probs[~true_pos, k]

    print("\n" + "="*80)
    print(f"Label: {label_name}  (index {k})")
    print(f"Support: {n_pos} | False Negatives @ thr={thr}: {n_fn} ({(n_fn/max(n_pos,1))*100:.1f}%)")
    if auc is not None:
        print(f"ROC-AUC: {auc:.4f}")

    print("Score stats:")
    print(f"  positives: mean={float(pos_scores.mean()):.4f}  median={float(np.median(pos_scores)):.4f}")
    print(f"  negatives: mean={float(neg_scores.mean()):.6f}  median={float(np.median(neg_scores)):.6f}")

    # Where do FNs go? (top-2 predicted labels)
    if n_fn > 0:
        top2_idx = np.argsort(probs[fn_idx], axis=1)[:, -2:][:, ::-1]
        top2_labels = [tuple(classes[j] for j in row) for row in top2_idx]
        pair_counts = Counter(top2_labels)

        print("\nMost common TOP-2 predicted label pairs for FNs:")
        for pair, cnt in pair_counts.most_common(topk_pairs):
            print(f"{cnt:4d}  {pair}")

        single_counts = Counter([lbl for pair in top2_labels for lbl in pair])
        print("\nMost common individual labels appearing in TOP-2 for FNs:")
        for lbl, cnt in single_counts.most_common(topk_pairs):
            print(f"{cnt:4d}  {lbl}")

        print("\nExamples (index | true labels | P(this label) | top2 preds):")
        for i in fn_idx[:10]:
            true_pair = tuple([classes[j] for j in np.where(Y_real[i] == 1)[0]])
            top2 = tuple(classes[j] for j in np.argsort(probs[i])[-2:][::-1])
            print(i, "|", true_pair, "|", f"{probs[i, k]:.3f}", "|", top2)

    # Histogram (optional)
    if plot:
        plt.figure()
        plt.hist(pos_scores, bins=bins, alpha=0.6, label=f"{label_name} TRUE present")
        plt.hist(neg_scores, bins=bins, alpha=0.6, label=f"{label_name} TRUE absent")
        plt.axvline(thr, linestyle="--", label=f"threshold={thr}")
        plt.xlabel(f"P({label_name}) = sigmoid(logit)")
        plt.ylabel("Count")
        plt.title(f"{label_name} score distribution (positive vs negative)")
        plt.legend()
        plt.show()


# Run for all labels that actually appear in the real set
for k in valid_idx:
    analyze_label_on_real(k, classes[k], Y_real, probs, thr=thr, topk_pairs=10, plot=False)
# Out:
# ================================================================================
# Label: 1-dodecanethiol  (index 1)
# Support: 243 | False Negatives @ thr=0.5: 28 (11.5%)
# ROC-AUC: 0.9421
# Score stats:
#   positives: mean=0.7737  median=0.7854
#   negatives: mean=0.088630  median=0.000000
#
# Most common TOP-2 predicted label pairs for FNs:
#   24  ('meoh', '1-undecanethiol')
#    1  ('meoh', '1,9-nonanedithiol')
#    1  ('1,9-nonanedithiol', '1-undecanethiol')
#    1  ('1,9-nonanedithiol', '6-mercapto-1-hexanol')
#    1  ('1-undecanethiol', 'meoh')
#
# Most common individual labels appearing in TOP-2 for FNs:
#   26  meoh
#   26  1-undecanethiol
#    3  1,9-nonanedithiol
#    1  6-mercapto-1-hexanol
#
# Examples (index | true labels | P(this label) | top2 preds):
# 267 | ('1-dodecanethiol', 'meoh') | 0.061 | ('meoh', '1-undecanethiol')
# 268 | ('1-dodecanethiol', 'meoh') | 0.493 | ('meoh', '1-undecanethiol')
# 269 | ('1-dodecanethiol', 'meoh') | 0.326 | ('meoh', '1-undecanethiol')
# 272 | ('1-dodecanethiol', 'meoh') | 0.495 | ('meoh', '1-undecanethiol')
# 273 | ('1-dodecanethiol', 'meoh') | 0.340 | ('meoh', '1-undecanethiol')
# 274 | ('1-dodecanethiol', 'meoh') | 0.288 | ('meoh', '1-undecanethiol')
# 275 | ('1-dodecanethiol', 'meoh') | 0.336 | ('meoh', '1-undecanethiol')
# 276 | ('1-dodecanethiol', 'meoh') | 0.357 | ('meoh', '1-undecanethiol')
# 278 | ('1-dodecanethiol', 'meoh') | 0.377 | ('meoh', '1-undecanethiol')
# 279 | ('1-dodecanethiol', 'meoh') | 0.332 | ('meoh', '1-undecanethiol')
#
# ================================================================================
# Label: 6-mercapto-1-hexanol  (index 3)
# Support: 108 | False Negatives @ thr=0.5: 72 (66.7%)
# ROC-AUC: 0.9893
# Score stats:
#   positives: mean=0.5024  median=0.3246
#   negatives: mean=0.014973  median=0.000001
#
# Most common TOP-2 predicted label pairs for FNs:
#   36  ('n,n-dimethylformamide', '1,9-nonanedithiol')
#   30  ('benzene', '1-dodecanethiol')
#    6  ('benzene', '1-undecanethiol')
#
# Most common individual labels appearing in TOP-2 for FNs:
#   36  benzene
#   36  n,n-dimethylformamide
#   36  1,9-nonanedithiol
#   30  1-dodecanethiol
#    6  1-undecanethiol
#
# Examples (index | true labels | P(this label) | top2 preds):
# 0 | ('6-mercapto-1-hexanol', 'benzene') | 0.269 | ('benzene', '1-dodecanethiol')
# 1 | ('6-mercapto-1-hexanol', 'benzene') | 0.291 | ('benzene', '1-dodecanethiol')
# 2 | ('6-mercapto-1-hexanol', 'benzene') | 0.291 | ('benzene', '1-dodecanethiol')
# 3 | ('6-mercapto-1-hexanol', 'benzene') | 0.232 | ('benzene', '1-dodecanethiol')
# 4 | ('6-mercapto-1-hexanol', 'benzene') | 0.291 | ('benzene', '1-dodecanethiol')
# 5 | ('6-mercapto-1-hexanol', 'benzene') | 0.256 | ('benzene', '1-dodecanethiol')
# 6 | ('6-mercapto-1-hexanol', 'benzene') | 0.311 | ('benzene', '1-undecanethiol')
# 7 | ('6-mercapto-1-hexanol', 'benzene') | 0.266 | ('benzene', '1-dodecanethiol')
# 8 | ('6-mercapto-1-hexanol', 'benzene') | 0.305 | ('benzene', '1-undecanethiol')
# 9 | ('6-mercapto-1-hexanol', 'benzene') | 0.298 | ('benzene', '1-dodecanethiol')
#
# ================================================================================
# Label: benzene  (index 4)
# Support: 193 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=1.0000  median=1.0000
#   negatives: mean=0.000000  median=0.000000
#
# ================================================================================
# Label: benzenethiol  (index 5)
# Support: 72 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=0.9969  median=0.9985
#   negatives: mean=0.040312  median=0.000000
#
# ================================================================================
# Label: etoh  (index 7)
# Support: 121 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=0.9831  median=1.0000
#   negatives: mean=0.000026  median=0.000000
#
# ================================================================================
# Label: meoh  (index 8)
# Support: 243 | False Negatives @ thr=0.5: 28 (11.5%)
# ROC-AUC: 0.9963
# Score stats:
#   positives: mean=0.8746  median=0.9987
#   negatives: mean=0.000000  median=0.000000
#
# Most common TOP-2 predicted label pairs for FNs:
#   10  ('1-dodecanethiol', '1-undecanethiol')
#    8  ('1,9-nonanedithiol', '1-dodecanethiol')
#    2  ('1,9-nonanedithiol', 'tris(2-ethylhexyl) phosphate')
#    2  ('tris(2-ethylhexyl) phosphate', '1,9-nonanedithiol')
#    1  ('1,9-nonanedithiol', '1-undecanethiol')
#    1  ('1,9-nonanedithiol', '6-mercapto-1-hexanol')
#    1  ('n,n-dimethylformamide', '1,9-nonanedithiol')
#    1  ('1,9-nonanedithiol', 'n,n-dimethylformamide')
#    1  ('1-undecanethiol', '1-dodecanethiol')
#    1  ('1-undecanethiol', 'meoh')
#
# Most common individual labels appearing in TOP-2 for FNs:
#   19  1-dodecanethiol
#   16  1,9-nonanedithiol
#   13  1-undecanethiol
#    4  tris(2-ethylhexyl) phosphate
#    2  n,n-dimethylformamide
#    1  6-mercapto-1-hexanol
#    1  meoh
#
# Examples (index | true labels | P(this label) | top2 preds):
# 297 | ('1-dodecanethiol', 'meoh') | 0.000 | ('1-dodecanethiol', '1-undecanethiol')
# 320 | ('1-dodecanethiol', 'meoh') | 0.001 | ('1-dodecanethiol', '1-undecanethiol')
# 323 | ('1-dodecanethiol', 'meoh') | 0.124 | ('1-dodecanethiol', '1-undecanethiol')
# 325 | ('1-dodecanethiol', 'meoh') | 0.000 | ('1-dodecanethiol', '1-undecanethiol')
# 326 | ('1-dodecanethiol', 'meoh') | 0.000 | ('1,9-nonanedithiol', '1-dodecanethiol')
# 327 | ('1-dodecanethiol', 'meoh') | 0.000 | ('1,9-nonanedithiol', '1-undecanethiol')
# 328 | ('1-dodecanethiol', 'meoh') | 0.000 | ('1,9-nonanedithiol', '1-dodecanethiol')
# 329 | ('1-dodecanethiol', 'meoh') | 0.002 | ('1,9-nonanedithiol', '6-mercapto-1-hexanol')
# 330 | ('1-dodecanethiol', 'meoh') | 0.017 | ('1,9-nonanedithiol', '1-dodecanethiol')
# 384 | ('1-dodecanethiol', 'meoh') | 0.170 | ('1-dodecanethiol', '1-undecanethiol')
#
# ================================================================================
# Label: n,n-dimethylformamide  (index 9)
# Support: 72 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 0.9985
# Score stats:
#   positives: mean=1.0000  median=1.0000
#   negatives: mean=0.022309  median=0.000000
#
# ================================================================================
# Label: pyridine  (index 10)
# Support: 108 | False Negatives @ thr=0.5: 0 (0.0%)
# ROC-AUC: 1.0000
# Score stats:
#   positives: mean=1.0000  median=1.0000
#   negatives: mean=0.000191  median=0.000000

# %%
summary = []
for k in valid_idx:
    true_pos = (Y_real[:, k] == 1)
    tp = int((true_pos & (probs[:, k] >= thr)).sum())
    fn = int((true_pos & (probs[:, k] <  thr)).sum())
    pos = int(true_pos.sum())
    recall = tp / (pos + 1e-12)

    auc = np.nan
    if len(np.unique(true_pos.astype(int))) == 2:
        auc = roc_auc_score(true_pos.astype(int), probs[:, k])

    summary.append((classes[k], pos, recall, fn, auc))

summary_sorted = sorted(summary, key=lambda x: x[2])  # sort by recall ascending

print("\nWorst recall labels on REAL mixtures @ thr=0.5:")
for name, pos, rec, fn, auc in summary_sorted[:10]:
    print(f"{name:30s} support={pos:4d} recall={rec:.3f} FN={fn:4d} AUC={auc:.3f}")
# Out:
# Worst recall labels on REAL mixtures @ thr=0.5:
# 6-mercapto-1-hexanol           support= 108 recall=0.333 FN=  72 AUC=0.989
# 1-dodecanethiol                support= 243 recall=0.885 FN=  28 AUC=0.942
# meoh                           support= 243 recall=0.885 FN=  28 AUC=0.996
# benzenethiol                   support=  72 recall=1.000 FN=   0 AUC=1.000
# n,n-dimethylformamide          support=  72 recall=1.000 FN=   0 AUC=0.999
# pyridine                       support= 108 recall=1.000 FN=   0 AUC=1.000
# etoh                           support= 121 recall=1.000 FN=   0 AUC=1.000
# benzene                        support= 193 recall=1.000 FN=   0 AUC=1.000

# %%
import numpy as np
import torch

# ---------- Synthetic test (from test_loader) ----------
model_boost.eval()
syn_logits_list, syn_true_list = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        syn_logits_list.append(model_boost(xb).cpu().numpy())  # logits
        syn_true_list.append(yb.cpu().numpy())                 # 0/1

logits_syn = np.vstack(syn_logits_list)      # (N_syn, C)
y_true_syn = np.vstack(syn_true_list).astype(int)
probs_syn  = 1 / (1 + np.exp(-logits_syn))   # sigmoid

# ---------- Real mixtures ----------
model_boost.eval()
with torch.no_grad():
    logits_real = model_boost(torch.tensor(mix_embeds, dtype=torch.float32)).cpu().numpy()
probs_real = 1 / (1 + np.exp(-logits_real))  # sigmoid
# Out:
# /tmp/ipykernel_24965/2724202452.py:14: RuntimeWarning: overflow encountered in exp
#   probs_syn  = 1 / (1 + np.exp(-logits_syn))   # sigmoid
# /tmp/ipykernel_24965/2724202452.py:20: RuntimeWarning: overflow encountered in exp
#   probs_real = 1 / (1 + np.exp(-logits_real))  # sigmoid

# %%
def compare_pos_distributions_all_labels(classes, y_true_syn, probs_syn, Y_real, probs_real):
    rows = []
    for k, name in enumerate(classes):
        syn_pos = probs_syn[y_true_syn[:, k] == 1, k]
        real_pos = probs_real[Y_real[:, k] == 1, k]

        # Skip if a label is missing in either set
        if syn_pos.size == 0 or real_pos.size == 0:
            continue

        rows.append({
            "label": name,
            "syn_pos_n": int(syn_pos.size),
            "real_pos_n": int(real_pos.size),
            "syn_pos_median": float(np.median(syn_pos)),
            "real_pos_median": float(np.median(real_pos)),
            "syn_pos_mean": float(np.mean(syn_pos)),
            "real_pos_mean": float(np.mean(real_pos)),
            # Negative means real is lower => left shift
            "median_shift_real_minus_syn": float(np.median(real_pos) - np.median(syn_pos)),
            "mean_shift_real_minus_syn": float(np.mean(real_pos) - np.mean(syn_pos)),
        })

    df = pd.DataFrame(rows)
    df = df.sort_values("median_shift_real_minus_syn")  # most negative shifts first
    return df

df_shift = compare_pos_distributions_all_labels(classes, y_true_syn, probs_syn, Y_real, probs_real)

print("Largest LEFT shifts (real positives much lower than synthetic positives):")
print(df_shift[[
    "label", "syn_pos_n", "real_pos_n",
    "syn_pos_median", "real_pos_median",
    "median_shift_real_minus_syn",
    "syn_pos_mean", "real_pos_mean",
    "mean_shift_real_minus_syn"
]].head(12).to_string(index=False))
# Out:
# Largest LEFT shifts (real positives much lower than synthetic positives):
#                 label  syn_pos_n  real_pos_n  syn_pos_median  real_pos_median  median_shift_real_minus_syn  syn_pos_mean  real_pos_mean  mean_shift_real_minus_syn
#  6-mercapto-1-hexanol        204         108        0.983973         0.324589                    -0.659384      0.886012       0.502377                  -0.383635
#       1-dodecanethiol        225         243        0.925181         0.785384                    -0.139797      0.870979       0.773676                  -0.097303
#          benzenethiol        195          72        1.000000         0.998518                    -0.001482      0.991390       0.996893                   0.005504
#                  meoh        184         243        0.999995         0.998716                    -0.001279      0.944219       0.874583                  -0.069636
# n,n-dimethylformamide        212          72        1.000000         0.999999                    -0.000001      0.992472       0.999998                   0.007525
#               benzene        235         193        1.000000         1.000000                     0.000000      1.000000       1.000000                   0.000000
#              pyridine        223         108        1.000000         1.000000                     0.000000      0.987149       1.000000                   0.012851
#                  etoh        217         121        0.999995         1.000000                     0.000005      0.972679       0.983064                   0.010385

# %%
from sklearn.metrics import precision_score, recall_score

def best_threshold_fbeta(y_true_bin, p, beta=2.0, grid=None):
    if grid is None:
        grid = np.linspace(0.01, 0.99, 99)

    best_t, best_f = 0.5, -1.0
    for t in grid:
        y_pred = (p >= t).astype(int)
        tp = np.sum((y_true_bin==1) & (y_pred==1))
        fp = np.sum((y_true_bin==0) & (y_pred==1))
        fn = np.sum((y_true_bin==1) & (y_pred==0))
        prec = tp/(tp+fp+1e-12)
        rec  = tp/(tp+fn+1e-12)
        f = (1+beta**2)*prec*rec/(beta**2*prec + rec + 1e-12)
        if f > best_f:
            best_f, best_t = f, float(t)
    return best_t, best_f

rows = []
thr0 = 0.5

for k, name in enumerate(classes):
    yk = Y_real[:, k]
    if yk.sum() == 0:
        continue  # label absent in real set

    pk = probs_real[:, k]

    # baseline @ 0.5
    base_pred = (pk >= thr0).astype(int)
    base_prec = precision_score(yk, base_pred, zero_division=0)
    base_rec  = recall_score(yk, base_pred, zero_division=0)

    # optimized threshold
    t_opt, f_opt = best_threshold_fbeta(yk, pk, beta=2.0)
    opt_pred = (pk >= t_opt).astype(int)
    opt_prec = precision_score(yk, opt_pred, zero_division=0)
    opt_rec  = recall_score(yk, opt_pred, zero_division=0)

    rows.append({
        "label": name,
        "support": int(yk.sum()),
        "base_thr": thr0,
        "base_prec": float(base_prec),
        "base_rec": float(base_rec),
        "opt_thr_F2": float(t_opt),
        "opt_prec": float(opt_prec),
        "opt_rec": float(opt_rec),
        "recall_gain": float(opt_rec - base_rec),
        "precision_change": float(opt_prec - base_prec),
    })

df_thr = pd.DataFrame(rows).sort_values("recall_gain", ascending=False)

print("Biggest recall gains from per-label thresholding (F2-optimized):")
print(df_thr[[
    "label","support","base_prec","base_rec",
    "opt_thr_F2","opt_prec","opt_rec",
    "recall_gain","precision_change"
]].head(12).to_string(index=False))
# Out:
# Biggest recall gains from per-label thresholding (F2-optimized):
#                 label  support  base_prec  base_rec  opt_thr_F2  opt_prec  opt_rec  recall_gain  precision_change
#  6-mercapto-1-hexanol      108   0.900000  0.333333        0.08  0.907563 1.000000     0.666667          0.007563
#       1-dodecanethiol      243   0.856574  0.884774        0.01  0.870504 0.995885     0.111111          0.013930
#                  meoh      243   1.000000  0.884774        0.01  1.000000 0.930041     0.045267          0.000000
#               benzene      193   1.000000  1.000000        0.01  1.000000 1.000000     0.000000          0.000000
#          benzenethiol       72   0.888889  1.000000        0.61  1.000000 1.000000     0.000000          0.111111
#                  etoh      121   1.000000  1.000000        0.01  1.000000 1.000000     0.000000          0.000000
# n,n-dimethylformamide       72   0.972973  1.000000        0.44  0.972973 1.000000     0.000000          0.000000
#              pyridine      108   1.000000  1.000000        0.01  1.000000 1.000000     0.000000          0.000000

# %%
merc = "6-mercapto-1-hexanol"
k = class_to_i[merc]

idx = np.where(Y_real[:, k] == 1)[0]          # indices where mercapto truly present
P = probs_real[idx]                           # (N_pos, C)

# rank 1 = best/highest prob
merc_scores = P[:, k]
# Count how many labels have strictly greater score than mercapto, add 1 => rank
ranks = (P > merc_scores[:, None]).sum(axis=1) + 1

print(f"{merc} rank on REAL positives (1=highest):")
print("  N positives:", len(idx))
print("  mean rank:", float(np.mean(ranks)))
print("  median rank:", float(np.median(ranks)))
print("  % rank<=2:", float(np.mean(ranks <= 2))*100)
print("  % rank<=3:", float(np.mean(ranks <= 3))*100)
print("  % rank<=4:", float(np.mean(ranks <= 4))*100)

# Optional: show most common ranks
unique_r, counts = np.unique(ranks, return_counts=True)
print("\nRank histogram (rank: count):")
for r, c in zip(unique_r[:10], counts[:10]):
    print(f"  {int(r)}: {int(c)}")

# Optional: for mercapto positives, who beats mercapto most often?
better = (P > merc_scores[:, None])  # (N_pos,C)
better[:, k] = False
counts_better = better.sum(axis=0)
top_confusers = np.argsort(counts_better)[::-1][:10]
print("\nLabels that outrank mercapto most often on mercapto-positive samples:")
for j in top_confusers:
    if counts_better[j] > 0:
        print(f"  {classes[j]:30s}  outranks mercapto in {int(counts_better[j])}/{len(idx)} samples")
# Out:
# 6-mercapto-1-hexanol rank on REAL positives (1=highest):
#   N positives: 108
#   mean rank: 3.3333333333333335
#   median rank: 3.0
#   % rank<=2: 0.0
#   % rank<=3: 66.66666666666666
#   % rank<=4: 100.0
#
# Rank histogram (rank: count):
#   3: 72
#   4: 36
#
# Labels that outrank mercapto most often on mercapto-positive samples:
#   1,9-nonanedithiol               outranks mercapto in 72/108 samples
#   pyridine                        outranks mercapto in 36/108 samples
#   benzene                         outranks mercapto in 36/108 samples
#   n,n-dimethylformamide           outranks mercapto in 36/108 samples
#   1-undecanethiol                 outranks mercapto in 36/108 samples
#   1-dodecanethiol                 outranks mercapto in 36/108 samples
